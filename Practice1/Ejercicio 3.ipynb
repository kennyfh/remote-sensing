# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load a color image
img = cv.imread('../img/ej3_img1.jpg')
print(img)
# Out:
# [[[ 42  43 195]
#   [ 42  42 188]
#   [ 28  33 165]
#   ...
#   [ 59  12  45]
#   [ 60  13  45]
#   [ 61  14  46]]
#
#  [[ 46  45 203]
#   [ 42  43 193]
#   [ 28  32 167]
#   ...
#   [ 61  14  47]
#   [ 60  13  46]
#   [ 60  13  45]]
#
#  [[ 42  40 206]
#   [ 38  37 195]
#   [ 24  25 169]
#   ...
#   [ 63  16  49]
#   [ 61  14  47]
#   [ 59  12  45]]
#
#  ...
#
#  [[ 35  24  57]
#   [ 35  24  57]
#   [ 35  24  57]
#   ...
#   [ 36  19  63]
#   [ 41  22  65]
#   [ 41  21  63]]
#
#  [[ 36  25  58]
#   [ 35  24  57]
#   [ 35  24  57]
#   ...
#   [ 34  19  63]
#   [ 35  16  59]
#   [ 29   9  51]]
#
#  [[ 36  25  58]
#   [ 36  25  58]
#   [ 36  25  58]
#   ...
#   [ 32  19  63]
#   [ 31  14  57]
#   [ 23   5  46]]]

# %%
"""
TODO: Describir la estructura de datos de la variable img
La imagen img está basada en en un Array Numpy en la que puede haber
solamente un canal o multicanal de n dimensiones.

Fuente:
https://github.com/opencv/opencv/wiki/FAQ
https://docs.opencv.org/4.5.3/d3/d63/classcv_1_1Mat.html#details
"""

# %%
plt.imshow(img)
plt.show()

# %%
print(f"La imágen es una matriz de tamaño: {img.shape} (px,px,canales))")
print(f"Esto es el pixel [100,100]: {img[100,100]}")
print(f"Esto es la fila 100: {img[100,:]}")
print(f"Esto es una submatriz: {img[100:200,100:200]}")
# Out:
# La imágen es una matriz de tamaño: (1270, 2000, 3) (px,px,canales))
# Esto es el pixel [100,100]: [12  4 14]
# Esto es la fila 100: [[ 35  26  82]
#  [ 36  27  83]
#  [ 38  29  85]
#  ...
#  [ 53  10 113]
#  [ 55  12 115]
#  [ 55  12 115]]
# Esto es una submatriz: [[[ 12   4  14]
#   [ 15   7  18]
#   [ 16   5  21]
#   ...
#   [ 22   8  20]
#   [ 25  10  24]
#   [ 27  11  28]]
#
#  [[ 13   5  16]
#   [ 17   7  23]
#   [ 16   5  25]
#   ...
#   [ 20   8  20]
#   [ 25  10  24]
#   [ 26  10  27]]
#
#  [[ 14   5  18]
#   [ 19   8  28]
#   [ 18   5  31]
#   ...
#   [ 20   8  20]
#   [ 21   8  22]
#   [ 22   8  26]]
#
#  ...
#
#  [[ 44  37 152]
#   [ 44  37 152]
#   [ 45  37 154]
#   ...
#   [ 59  48 111]
#   [ 62  51 114]
#   [ 64  53 116]]
#
#  [[ 45  38 153]
#   [ 45  38 153]
#   [ 46  38 155]
#   ...
#   [ 65  54 117]
#   [ 64  53 116]
#   [ 64  53 116]]
#
#  [[ 45  38 153]
#   [ 46  39 154]
#   [ 46  38 155]
#   ...
#   [ 64  53 116]
#   [ 62  51 114]
#   [ 60  48 114]]]

# %%
b,g,r = cv.split(img)
img_rgb = cv.merge((r,g,b))
plt.imshow(img_rgb)
plt.show()

# %%
guante= img[0:400,400:800]               
lenx,leny,ch = guante.shape
print(guante.shape)
img[600:600+lenx,100:100+leny]=guante
img[600:600+lenx,500:500+leny]=guante               
img[600:600+lenx,900:900+leny]=guante               
plt.imshow(cv.cvtColor(img,cv.COLOR_BGR2RGB))
plt.show()
# Out:
# (400, 400, 3)

# %%
# Save img
cv.imwrite("EJmodificado.png",img)
# Out:
# True
