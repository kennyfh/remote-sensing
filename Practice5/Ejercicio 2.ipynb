# %%
# Importación módulos
import sys
import numpy as np
np.set_printoptions(threshold=10000)
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ruta =  '../imgpack/Monobanda/2_Corsica.jpg'

# %%
#Función pseudo
def seudo(img_path,min_,max_):
    img = cv.imread(img,cv.IMREAD_GRAYSCALE)
    resimg = np.zeros((img.shape[0],img.shape[1],3), np.uint8)
    for x in range(img.shape[0]):
        for y in range(img.shape[1]):
            pix = img[x,y]
            if pix >=min_ and pix<=max_:
                resimg[x,y]= (255,0,0)
            else:
                resimg[x,y]= (pix,pix,pix)
    
    return resimg

# %%
img_exp = seudo(ruta,140,160)

# %%
#Los picos los pinte de rojo
fig = plt.figure(figsize=(15, 15)) # Creamos nueva figura

fig.add_subplot(221)
plt.imshow(img_exp)
plt.show()
